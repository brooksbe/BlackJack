# %%
cardID={0:'Ace', 1:'Two',2:'Three',3:'Four',4:'Five',5:'Six',6:'Seven',7:'Eight',8:'Nine',9:'Ten',10:'Jack',11:'Queen',12:'King'}
suitID={0:'Clubs', 1:'Diamonds',2:'Hearts',3:'Spades'}
usedCard=[]
import random as rdm

def main():
    print('')
    print('Welcome to my Black Jack table!')
    print('')
    print('We are playing with 6 decks and we are not splitting doubles')
    rules()
    
    numPlyr = numPlayer()
    
    numDk = 6
    
    play = 'y'
    
    deck=mkDeck(numDk)

    mnyBlt = mkFunds(numPlyr)


    dltCrds={}
    while play == 'x' or play=='Y' or play=='y' or play=='yes':
        print('')
        bt = anteUp(numPlyr)
        
        dltCrds=pickTwo(numPlyr,numDk,deck,dltCrds)

        showPlayers(numPlyr,dltCrds)

        dealer2(dltCrds,numDk,deck)

        showDealer1(dltCrds)
        
        dealer=tallyCard('Dealer',dltCrds)
        if dealer != 21:
            print('')
            print('The dealer has a natural Black Jack!')
            for i in range(numPlyr):
                displayCard(i,dltCrds)
                dltCrds = playerHit(i,dltCrds,numDk,deck)
                plaVal = tallyCard(i,dltCrds)
                commentaryPlayer(plaVal)

            showDealer2(dltCrds)

            dealerHit(dltCrds,deck,numDk)

            commentaryDealer(dltCrds)
        else:
            showDealer2(dltCrds)
        
        finalScore(numPlyr,dltCrds,bt,mnyBlt)
    
        if len(dltCrds['used'])>=250:
            deck=mkDeck(numDk)
            dltCrds={}
            print('')
            print('The dealer is taking a moment to shuffle the cards')
        print('')
        play = input("Would you like to play again? (Y or no): ")
    thankYou(numPlyr,mnyBlt)
    
def thankYou(numPlyr,mnyBlt):
    print('')
    print('Thank you for playing my version of Black Jack!')
    print('')
    i=0
    for i in range(numPlyr):
        print('Player',i+1,' is leaving with $',mnyBlt[i])
        print('')
        
def rules():
    rules = input('\nWould you like to know the rules of the game(Y/N)? ')
    if rules=='Y' or rules=='y' or rules=='yes':
        print('\nThe object of the game is to get 21. \n'\
              'Each player is delt two cards face up. Aces are either 1 or 11, players choice and face cards are 10. \n'\
              'The value of the players\'s cards are added together. The player would like to get as close to 21 in \n'\
              'order to win. If the total is higher than 21 the player automatically loses. \n\n'\
              'If no one wins after the first two cards players add more cards from the deck by saying Hit.'\
              'More cards can be added until the player achieves 21 or goes to for or when they decide to stop. \n\n'\
              'The dealer on the other hand must add cards until the total is 17 or higher and then the dealer must stop.'\
              'Of course the dealer may also get 21 or bust. Everyone who gets 21 wins.'\
              'If the dealer gets 21 everyone loses except for the players that also have 21. '\
              'Otherwise whoever has the highest total who does not bust wins.')
        
def numPlayer():
    player = 0
    print("")
    while player < 1 or player >9:
        player = input("How many players are playing today? Please use an integer between 1-9. ") #note: error handling 1-9?
        while player.isdigit() == False:
            player = input('\nInvalid input, please enter an integer: ')
        player = int(player)
        print("Players =",player)
    return player

def mkFunds(numPlyr):
    thousands = 0
    moneybelt={}
    while thousands < 1 or thousands >100:
        thousands = input("How many thousands of dollars are we playing with today? Please use an integer between 1-100. ") #note: error handling 1-9?
        while thousands.isdigit() == False:
            thousands = input('\nInvalid input, please enter an integer: ')
        thousands = int(thousands)
    for i in range(numPlyr):
        moneybelt[i]=thousands*1000
    return moneybelt

def anteUp(numPlyr):
    bet={}
    for i in range(numPlyr):
        print('Player',i+1,':')
        ante = input ('Make a bet between $2 and $5000: ')
        while ante.isdigit() == False:
            ante = input('\nInvalid input, please enter an integer: ')
        ante = int(ante)
        bet[i]=ante
    return bet

def numDeck():
    numDk = 0
    print("")
    while numDk < 1 or numDk >9:
        numDk = input("How many decks are we playing with today? Please use an integer between 1-9. ") #note: error handling 1-9?
        while numDk.isdigit() == False:
            numDk = input('\nInvalid input, please enter an integer: ')
        numDk = int(numDk)
    return numDk

def mkDeck(numDk):
    x=y=i=0
    card=[]
    while i<4:
        x=i
        j=0
        while j<13:
            y=j
            z=[x,y]
            card.append(z)
            j+=1
        i+=1
    dupCard=[] 
    while numDk >0:
        dupCard=dupCard+card
        numDk -= 1
        
    count = i = 0 
    deck = {}  # Empty dictionary to add values into
    for i in dupCard:
        deck[count] = i
        count += 1 
    return deck

def pickTwo(numPlyr,numDk,deck,dltCrds):
    players2=[]
    dealtCards=dltCrds
    j=0
    for j in range(numPlyr):
        i=0
        players2=[]
        for i in range(2):
            random=rdm.randint(0,(52*numDk-1))
            while random in usedCard:
                random=rdm.randint(0,(52*numDk-1))
            card = deck.get(random)
            players2.append(card)
            usedCard.append(random)
            i+=1
        dealtCards[j]=players2 
        j += 1
    dealtCards['used']=usedCard
    return dealtCards

def dealer2(dltCrds,numDk,deck):
    i=0
    dealer2=[]
    card =[]
    usedCard=dltCrds['used']
    for i in range(2):
        random=rdm.randint(0,(52*numDk-1))
        while random in usedCard:
            random=rdm.randint(0,(52*numDk-1))
        card = deck.get(random)
        dealer2.append(card)
        dltCrds['used'].append(random)
        i+=1
    dltCrds['Dealer']=dealer2   
#     print(dltCrds)
    return dltCrds

def displayCard(playerID,dltCrds):
    plaCard = dltCrds.get(playerID)
    i=0
    print('')
    print("Cards for Player", playerID + 1 ,"\n")
    for i in range(len(plaCard)):
        print("  Card",i+1,"is the",cardID[plaCard[i][1]],"of",suitID[plaCard[i][0]])
        i+=1

def tallyCard(playerID,dltCrds):
    plaCard = dltCrds.get(playerID)
    plaVal=0
    val=0
    i=0
    hasAce=False
    for i in range(len(plaCard)):
        if plaCard[i][1] == 0:
            hasAce = True
            x = 11
#             print('A',val,plaCard[i][1]) # Test that this case happened
        elif plaCard[i][1] in range(1,10):
            x = plaCard[i][1]+1
#             print('B',x,plaCard[i][1]) # Test that this case happened
        else:
            x = 10
#             print('C',x,plaCard[i][1]) # Test that this case happened
        plaVal = plaVal + x
    if plaVal>21 and hasAce ==True:
        plaVal = plaVal - 10
    return plaVal

def commentaryPlayer(plaVal):
    print("")
    print("  Total of",plaVal,"points")
    if plaVal == 21:
        print("Black Jack! . . . Sweeeeeet! But we need to check the dealer...")
    elif plaVal > 21:
        print("Bummer! You busted!")

def playerHit(playerID,dltCrds,numDk,deck):      #player hit Adds card to end of player card
    random = 0
    hit ='x'
    plaVal = tallyCard(playerID,dltCrds)
    if plaVal >=21:
        hit ='n'
    while hit == 'x' or hit=='Y' or hit=='y' or hit=='yes':
        hit = input('\nWould you like to Hit(Y/N)? ')
        if hit=='Y' or hit=='y' or hit=='yes':
            random=rdm.randint(0,(52*numDk-1))
            while random in dltCrds['used']:
                random=rdm.randint(0,(52*numDk-1))
            card = deck.get(random)
            dltCrds[playerID].append(card)
            dltCrds['used'].append(random)
            print('')
            print("  The player recieved a",cardID[card[1]],"of",suitID[card[0]])
            plaVal = tallyCard(playerID,dltCrds)
            if plaVal >=21:
                break
        else:
            print('')
            print("  The player stands.")
    return dltCrds

def showPlayers(numPlyr,dltCrds):
    i = 0
    for i in range(numPlyr):
        print("")
        displayCard(i,dltCrds)
        plaVal=tallyCard(i,dltCrds)
        commentaryPlayer(plaVal)
        
def showDealer1(dltCrds):
    print("")
    print("Cards for Dealer \n")
    print("  Card 1 is the",cardID[dltCrds['Dealer'][0][1]],"of",suitID[dltCrds['Dealer'][0][0]])
    print("  The second card remains face down for now")

def showDealer2(dltCrds):
    print("")
    print("Cards for Dealer \n")
    print("  Card 1 is the",cardID[dltCrds['Dealer'][0][1]],"of",suitID[dltCrds['Dealer'][0][0]])
    print("  Card 2 is the",cardID[dltCrds['Dealer'][1][1]],"of",suitID[dltCrds['Dealer'][1][0]])

def commentaryDealer(dltCrds):
    dealVal = tallyCard('Dealer',dltCrds)
    plaCard = dltCrds.get('Dealer')
    i=0
    print("")
    print("  The dealer has a total of",dealVal,"points")
    if dealVal == 21:
        print("Black Jack! . . . Bummer for the players...")
    elif dealVal > 21:
        print("Yes! The dealer busted!")    

def dealerHit(dltCrds,deck,numDk):    
    dealVal = tallyCard('Dealer',dltCrds)
    while dealVal <17:
        random=rdm.randint(0,(52*numDk-1))
        while random in dltCrds['used']:
            random=rdm.randint(0,(52*numDk-1))
        card = deck.get(random)
        print("")
        print("The dealer had less than 17 points and was required to hit.")
        print("  The dealer recieved a",cardID[card[1]],"of",suitID[card[0]])
        dltCrds['Dealer'].append(card)
        dltCrds['used'].append(random)
        dealVal = tallyCard('Dealer',dltCrds)
        if dealVal >=21:
            break
    return dltCrds
    

def finalScore(numPlyr,dltCrds,bt,mnyBlt):
    i = 0
    dealVal = tallyCard('Dealer',dltCrds)
    print('')
    print('+++++++++++++++++')
    print('')
    print('In Summary...')
    for i in range(numPlyr):
        print("")
        plaVal = tallyCard(i,dltCrds)
        if plaVal > 21:
            print('Player',i+1,', you busted! Better luck next time')
            mnyBlt[i]=mnyBlt[i]-bt[i]
            print('You lose',bt[i],'and have',mnyBlt[i],'left in your account')
        elif dealVal >21:
            print('Dealer busted! You are in luck')
            mnyBlt[i]=mnyBlt[i]+bt[i]
            print('You win',bt[i],'and have',mnyBlt[i],'in your account')
        elif plaVal > dealVal:
            print('Player',i+1,', you beat the dealer!',plaVal,'to',dealVal,' Awesome! You win')
            mnyBlt[i]=mnyBlt[i]+bt[i]
            print('You win',bt[i],'and have',mnyBlt[i],'in your account')
        elif plaVal == dealVal:
            print('Player',i+1,", it\'s a draw with the dealer.",plaVal,'to',dealVal,'. No one wins')
            print('You get your initial bet back and still have',mnyBlt[i],'left in your account')
        elif plaVal == 21 and plaVal != dealVal:
            print('Player',i+1,', you got Black Jack and win big!')
            mnyBlt[i]=mnyBlt[i]+1.5*bt[i]
            print('You have',int(mnyBlt[i]),'in your account')
        elif dealVal > plaVal:
            print('Player',i+1,', you lost to the dealer!',plaVal,'to',dealVal,' Better luck next time!')
            mnyBlt[i]=mnyBlt[i]-bt[i]
            print('You lose',bt[i],'and have',mnyBlt[i],'left in your account')
    return bt
    
main()
# Out:
# Welcome to Black Jack!
# We are playing with 6 decks and we are not splitting doubles!

# %% [markdown]
# Betting
# Before the deal begins, each player places a bet, in chips, in front of them in the designated area. Minimum and maximum limits are established on the betting, and the general limits are from $2 to $500.
#
# If a player's first two cards are an ace and a "ten-card" (a picture card or 10), giving a count of 21 in two cards, this is a natural or "blackjack." If any player has a natural and the dealer does not, the dealer immediately pays that player one and a half times the amount of their bet. If the dealer has a natural, they immediately collect the bets of all players who do not have naturals, (but no additional amount). If the dealer and another player both have naturals, the bet of that player is a stand-off (a tie), and the player takes back his chips.
#
# If the dealer's face-up card is a ten-card or an ace, they look at their face-down card to see if the two cards make a natural. If the face-up card is not a ten-card or an ace, they do not look at the face-down card until it is the dealer's turn to play.
#
# Splitting Pairs
# If a player's first two cards are of the same denomination, such as two jacks or two sixes, they may choose to treat them as two separate hands when their turn comes around. The amount of the original bet then goes on one of the cards, and an equal amount must be placed as a bet on the other card. The player first plays the hand to their left by standing or hitting one or more times; only then is the hand to the right played. The two hands are thus treated separately, and the dealer settles with each on its own merits. With a pair of aces, the player is given one card for each ace and may not draw again. Also, if a ten-card is dealt to one of these aces, the payoff is equal to the bet (not one and one-half to one, as with a blackjack at any other time).
#
# Doubling Down
# Another option open to the player is doubling their bet when the original two cards dealt total 9, 10, or 11. When the player's turn comes, they place a bet equal to the original bet, and the dealer gives the player just one card, which is placed face down and is not turned up until the bets are settled at the end of the hand. With two fives, the player may split a pair, double down, or just play the hand in the regular way. Note that the dealer does not have the option of splitting or doubling down.
#
# Insurance
# When the dealer's face-up card is an ace, any of the players may make a side bet of up to half the original bet that the dealer's face-down card is a ten-card, and thus a blackjack for the house. Once all such side bets are placed, the dealer looks at the hole card. If it is a ten-card, it is turned up, and those players who have made the insurance bet win and are paid double the amount of their half-bet - a 2 to 1 payoff. When a blackjack occurs for the dealer, of course, the hand is over, and the players' main bets are collected - unless a player also has blackjack, in which case it is a stand-off. Insurance is invariably not a good proposition for the player, unless they are quite sure that there are an unusually high number of ten-cards still left undealt.
#
# Settlement
# A bet once paid and collected is never returned. Thus, one key advantage to the dealer is that the player goes first. If the player goes bust, they have already lost their wager, even if the dealer goes bust as well. If the dealer goes over 21, the dealer pays each player who has stood the amount of that player's bet. If the dealer stands at 21 or less, the dealer pays the bet of any player having a higher total (not exceeding 21) and collects the bet of any player having a lower total. If there is a stand-off (a player having the same total as the dealer), no chips are paid out or collected.
#
# Reshuffling
# When each player's bet is settled, the dealer gathers in that player's cards and places them face up at the side against a clear plastic L-shaped shield. The dealer continues to deal from the shoe until coming to the plastic insert card, which indicates that it is time to reshuffle. Once that round of play is over, the dealer shuffles all the cards, prepares them for the cut, places the cards in the shoe, and the game continues.
